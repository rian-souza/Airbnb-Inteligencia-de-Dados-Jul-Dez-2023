# %% [markdown]
# <a href="https://colab.research.google.com/github/rian-souza/Airbnb-Inteligencia-de-Dados-Jul-Dez-2023/blob/main/Airbnb_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("/content/Airbnb_site_hotel new.csv")

df.head()
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15793 entries, 0 to 15792
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         15793 non-null  int64
#  1   name                       15793 non-null  object
#  2   host_id                    15793 non-null  int64
#  3   host_name                  15793 non-null  object
#  4   city                       15793 non-null  object
#  5   price                      15793 non-null  int64
#  6   reply time                 15793 non-null  int64
#  7   guest favourite            15793 non-null  int64
#  8   host since                 15793 non-null  int64
#  9   host Certification         14866 non-null  float64
#  10  room_type                  15792 non-null  float64
#  11  host total listings count  15792 non-null  float64
#  12  consumer                   15792 non-null  object
# ...
